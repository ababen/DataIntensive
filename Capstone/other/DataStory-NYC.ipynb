# %%
import pandas as pd

# %%
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pylab as plt
import seaborn as sns
#import ggplot as gg
from ggplot import *
import bokeh as bkh

# %%
from IPython.core.display import HTML
css = open('other/style-table.css').read() + open('other/style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %% [markdown]
# # Assignment
#
# How does one go about creating a data story? You have some pointers from the material you've just gone through, but they’re probably a bit on the abstract side when you’re just getting started. Also, storytelling is an art, so you have to get your imagination going. Here are some pointers to get those creative juices flowing. In the following sections we will work step-by-step to create your first Data Story
#
# 1. Pick a dataset - ideally the dataset for your Capstone. If for some reason you want to do this on a different data set, you can find one on Mode Analytics or Google's public data sets directory, or pick another one you like from elsewhere.
# 2. Get going by asking the following questions and looking for the answers with some code and plots:
#   1. Can you count something interesting?
#   2. Can you find some trends (high, low, increase, decrease, anomalies)?
#   3. Can you make a bar plot or a histogram?
#   4. Can you compare two related quantities?
#   5. Can you make a scatterplot?
#   6. Can you make a time-series plot?
# 3. Having made these plots, what are some insights you get from them? Do you see any correlations? Is there a hypothesis you would like to investigate further? What other questions do they lead you to ask?
# 4. By now you’ve asked a bunch of questions, and found some neat insights. Is there an interesting narrative, a way of presenting the insights using text and plots from the above, that tells a compelling story? As you work out this story, what are some other trends/relationships you think will make it more complete?
#
# Submission Requirements: Submit links to a Github repository containing a Jupyter notebook. The notebook should contain:
# 1. The questions you asked
# 2. The trends you investigated
# 3. The resulting visualizations and conclusions.
#
# In case the data set is too large to commit to Github, please include a link to the data set inside the Jupyter notebook

# %%
# Load New York City salaries dataset from OpenData
nyc = pd.read_csv('data/nyc/Citywide_Payroll_Data__Fiscal_Year_.csv', dtype={7: object})

# %% [markdown]
# # Staring with New York City salaries dataset

# %%
# Removing columns I do not intend to use
nyc = nyc.drop(nyc.columns[[1,7,10]], axis=1)

# %%
nyc.head()
# Out:
#    Fiscal Year                     Agency Name  Last Name First Name Mid Init  \
# 0         2014  OFFICE OF THE MAYOR                MULLEN     ALFRED        J
# 1         2014  OFFICE OF THE MAYOR               GARRETT  CORNELIUS        S
# 2         2014  OFFICE OF THE MAYOR               LEONARD      DIANE        M
# 3         2014  OFFICE OF THE MAYOR                  ROSS       JEAN        A
# 4         2014  OFFICE OF THE MAYOR             WEINSTOCK      SUSAN      NaN
#
#   Agency Start Date                                  Title Description  \
# 0        03/20/1972  CALENDAR ASSISTANT                            ...
# 1        09/25/1976  FISCAL RESPONSIBILITY OFFICER                 ...
# 2        11/22/1977  EXECUTIVE ASSISTANT-MIDTOWN ENFORCEMENT       ...
# 3        07/01/1978  ADMINISTRATIVE MANAGER                        ...
# 4        07/01/1978  ADMINISTRATIVE PRINTING SERVICES MANAGER      ...
#
#   Leave Status as of July 31   Pay Basis  Regular Hours Regular Gross Paid  \
# 0        ON SEPARATION LEAVE   per Annum         1825.0          $83096.78
# 1        ON SEPARATION LEAVE   per Annum         1825.0          $70790.46
# 2                     ACTIVE    per Hour         1573.0          $63165.38
# 3                     ACTIVE   per Annum         1825.0         $125370.69
# 4                     ACTIVE   per Annum         1825.0          $84268.60
#
#    OT Hours Total OT Paid Total Other Pay
# 0       0.0       $228.03           $0.00
# 1      10.5       $845.07           $0.00
# 2       0.0         $0.00           $0.00
# 3       0.0         $0.00           $0.00
# 4       0.0         $0.00           $0.00

# %%
# Removing spaces in column names.
nyc.rename(columns=lambda x: x.replace(" ", "_"), inplace=True)

# %%
# Removing the $ (the dollar sign) to convert to numeric
nyc['Regular_Gross_Paid'] = nyc['Regular_Gross_Paid'].str.lstrip('$')
nyc['Total_OT_Paid'] = nyc['Total_OT_Paid'].str.lstrip('$')
nyc['Total_Other_Pay'] = nyc['Total_Other_Pay'].str.lstrip('$')

# %%
# Converting to_numeric() for quantatative anlysis
nyc['Regular_Gross_Paid'] = pd.to_numeric(nyc['Regular_Gross_Paid'])
nyc['Total_OT_Paid'] = pd.to_numeric(nyc['Total_OT_Paid'])
nyc['Total_Other_Pay'] = pd.to_numeric(nyc['Total_Other_Pay'])

# %%
# Confirming converstion worked
nyc.dtypes
# Out:
# Fiscal_Year                     int64
# Agency_Name                    object
# Last_Name                      object
# First_Name                     object
# Mid_Init                       object
# Agency_Start_Date              object
# Title_Description              object
# Leave_Status_as_of_July_31     object
# Pay_Basis                      object
# Regular_Hours                 float64
# Regular_Gross_Paid            float64
# OT_Hours                      float64
# Total_OT_Paid                 float64
# Total_Other_Pay               float64
# dtype: object

# %%
# Lets look at the total amount of rows in NYC salaries dataset
len(nyc)
# Out:
# 1691487

# %%
# Creating the TotalPay column which combines all pay fields.
nyc['TotalPay'] = nyc.Regular_Gross_Paid + nyc.Total_OT_Paid + nyc.Total_Other_Pay

# %%
# This honestly doesnt tell me anything.
nyc.describe()
# Out:
#         Fiscal_Year  Regular_Hours  Regular_Gross_Paid      OT_Hours  \
# count  1.691487e+06   1.691486e+06        1.691486e+06  1.691486e+06
# mean   2.015021e+03   7.022911e+02        3.996266e+04  6.443838e+01
# std    7.892326e-01   9.041001e+02        3.665592e+04  1.519441e+02
# min    2.014000e+03  -7.304300e+02       -2.986219e+04 -8.000000e+00
# 25%    2.014000e+03   0.000000e+00        3.651787e+03  0.000000e+00
# 50%    2.015000e+03   0.000000e+00        3.518840e+04  0.000000e+00
# 75%    2.016000e+03   1.825000e+03        7.172129e+04  8.000000e+00
# max    2.016000e+03   4.171430e+03        6.723089e+05  3.347500e+03
#
#        Total_OT_Paid  Total_Other_Pay      TotalPay
# count   1.691486e+06     1.691486e+06  1.691486e+06
# mean    3.440764e+03     2.302203e+03  4.570563e+04
# std     8.886150e+03     5.083747e+03  4.379493e+04
# min    -2.382685e+04    -2.815950e+05 -1.740880e+05
# 25%     0.000000e+00     0.000000e+00  3.710333e+03
# 50%     0.000000e+00     8.200000e-01  3.738725e+04
# 75%     4.109350e+02     1.686587e+03  7.690195e+04
# max     2.286338e+05     1.003558e+05  6.727313e+05

# %%
# Here we see that there is a lot of cleaning we need to do here...
nyc[nyc.TotalPay < 10000]
# 1691338      NaN        06/25/2007
# 1691346      NaN        05/18/2015
# 1691351      NaN        05/18/2015
# 1691355        L        08/09/2009
# 1691366      NaN        04/02/2012
# 1691376        M        12/05/2011
# 1691382        T        06/10/2007
# 1691383        A        05/23/2005
# 1691384      NaN        06/24/2013
# 1691387        T        07/06/2009
# 1691390      NaN        05/18/2015
# 1691391      NaN        05/18/2015
# 1691395      NaN        05/19/2014
# 1691396      NaN        09/10/2006
# 1691405      NaN        03/31/2003
# 1691414        A        01/03/2011
# 1691416        M        03/24/2003
# 1691424      NaN        05/19/2014
# 1691434        A        09/07/2009
# 1691445        E        10/10/2012
# 1691450        A        07/20/2009
# 1691451      NaN        05/18/2015
# 1691453      NaN        06/08/2015
# 1691486      NaN        05/11/2015
#
#                                          Title_Description  \
# 23       MAYORAL OFFICE ASSISTANT                      ...
# 62       MAYORAL OFFICE ASSISTANT                      ...
# 114      MAYOR                                         ...
# 146      MAYORAL OFFICE ASSISTANT                      ...
# 198      MAYORAL OFFICE ASSISTANT                      ...
# 201      EXECUTIVE AGENCY COUNSEL                      ...
# 211      ADMINISTRATIVE PROJECT MANAGER                ...
# 229      ASSISTANT LEGISLATIVE REPRESENTATIVE          ...
# 230      MAYORAL OFFICE ASSISTANT                      ...
# 267      MAYORAL OFFICE ASSISTANT                      ...
# 279      ADMINISTRATIVE MANAGER                        ...
# 293      ADMINISTRATIVE STAFF ANALYST                  ...
# 318      DEPUTY MAYOR                                  ...
# 347      RESEARCH PROJECTS COORD                       ...
# 351      RESEARCH PROJECTS COORD                       ...
# 374      SPECIAL ASSISTANT                             ...
# 379      RESEARCH PROJECTS COORD                       ...
# 437      SPECIAL ASSISTANT                             ...
# 442      MAYORAL OFFICE ASSISTANT                      ...
# 446      MAYORAL OFFICE ASSISTANT                      ...
# 447      MAYORAL OFFICE ASSISTANT                      ...
# 448      MAYORAL OFFICE ASSISTANT                      ...
# 449      MAYORAL OFFICE ASSISTANT                      ...
# 450      MAYORAL OFFICE ASSISTANT                      ...
# 453      MAYORAL OFFICE ASSISTANT                      ...
# 457      MAYORAL OFFICE ASSISTANT                      ...
# 469      MAYORAL OFFICE ASSISTANT                      ...
# 512      MAYORAL OFFICE ASSISTANT                      ...
# 531      MAYORAL OFFICE ASSISTANT                      ...
# 532      MAYORAL OFFICE ASSISTANT                      ...
# ...                                                    ...
# 1691290  COMMUNITY ASSOCIATE                           ...
# 1691307  COLLEGE AIDE                                  ...
# 1691311  COLLEGE AIDE                                  ...
# 1691326  ASSISTANT DISTRICT ATTORNEY                   ...
# 1691331  COMMUNITY ASSOCIATE                           ...
# 1691332  COLLEGE AIDE                                  ...
# 1691338  COMMUNITY ASSOCIATE                           ...
# 1691346  COLLEGE AIDE                                  ...
# 1691351  COLLEGE AIDE                                  ...
# 1691355  COMMUNITY ASSOCIATE                           ...
# 1691366  COMMUNITY ASSOCIATE                           ...
# 1691376  ASSISTANT DISTRICT ATTORNEY                   ...
# 1691382  COMMUNITY ASSOCIATE                           ...
# 1691383  COMMUNITY COORDINATOR                         ...
# 1691384  COMMUNITY COORDINATOR                         ...
# 1691387  ASSISTANT DISTRICT ATTORNEY                   ...
# 1691390  COLLEGE AIDE                                  ...
# 1691391  COLLEGE AIDE                                  ...
# 1691395  COLLEGE AIDE                                  ...
# 1691396  COMMUNITY ASSOCIATE                           ...
# 1691405  COMMUNITY ASSOCIATE                           ...
# 1691414  COMMUNITY ASSOCIATE                           ...
# 1691416  ASSISTANT DISTRICT ATTORNEY                   ...
# 1691424  COLLEGE AIDE                                  ...
# 1691434  ASSISTANT DISTRICT ATTORNEY                   ...
# 1691445  COMMUNITY ASSOCIATE                           ...
# 1691450  COMMUNITY ASSOCIATE                           ...
# 1691451  COLLEGE AIDE                                  ...
# 1691453  COMMUNITY ASSOCIATE                           ...
# 1691486  ASSISTANT DISTRICT ATTORNEY                   ...
#
#         Leave_Status_as_of_July_31   Pay_Basis  Regular_Hours  \
# 23                        ON LEAVE   per Annum         -83.25
# 62                          CEASED   per Annum           0.00
# 114                         CEASED   per Annum           1.00
# 146                       ON LEAVE   per Annum         102.47
# 198                         CEASED   per Annum           0.00
# 201                         CEASED   per Annum          35.00
# 211                         CEASED   per Annum           0.00
# 229                         CEASED   per Annum           0.00
# 230                         CEASED   per Annum           0.00
# 267                         ACTIVE    per Hour         284.25
# 279                         CEASED   per Annum           0.00
# 293                         CEASED   per Annum           0.00
# 318                         CEASED   per Annum           1.00
# 347                         CEASED   per Annum           0.00
# 351                         CEASED   per Annum           0.00
# 374                         CEASED   per Annum         154.33
# 379                         CEASED   per Annum           0.00
# 437                         CEASED   per Annum         100.00
# 442                         CEASED    per Hour           0.00
# 446                         CEASED    per Hour         104.02
# 447                         CEASED    per Hour           0.00
# 448                         CEASED    per Hour          97.82
# 449                         CEASED    per Hour         103.60
# 450                         CEASED    per Hour         104.38
# 453                         CEASED    per Hour         283.00
# 457                         CEASED    per Hour          63.00
# 469                         CEASED    per Hour         373.33
# 512                         CEASED   per Annum         211.25
# 531                         CEASED    per Hour         225.50
# 532                         CEASED   per Annum         266.00
# ...                            ...         ...            ...
# 1691290                     CEASED   per Annum           0.00
# 1691307                     ACTIVE    per Hour           0.00
# 1691311                     ACTIVE    per Hour           0.00
# 1691326                     CEASED   per Annum           0.00
# 1691331                     CEASED   per Annum           0.00
# 1691332                     ACTIVE    per Hour           0.00
# 1691338                     CEASED   per Annum           0.00
# 1691346                     ACTIVE    per Hour           0.00
# 1691351                     ACTIVE    per Hour           0.00
# 1691355                     CEASED   per Annum           0.00
# 1691366                     CEASED   per Annum           0.00
# 1691376                     CEASED   per Annum           0.00
# 1691382                     CEASED   per Annum           0.00
# 1691383                     CEASED   per Annum           0.00
# 1691384                     CEASED   per Annum          95.00
# 1691387                     CEASED   per Annum           0.00
# 1691390                     ACTIVE    per Hour           0.00
# 1691391                     ACTIVE    per Hour           0.00
# 1691395                     CEASED    per Hour           0.00
# 1691445               61.59      0.00           0.00             0.00
# 1691450              282.68      0.00           1.42             0.00
# 1691451             1500.00      0.00           0.00             0.00
# 1691453              958.90      1.50           0.00             0.00
# 1691486             7526.45      0.00           0.00             0.00
#
#          TotalPay
# 23        3812.38
# 62        1199.13
# 114          1.00
# 146       2117.44
# 198       1869.90
# 201       6655.96
# 211       1118.77
# 229        230.11
# 230        115.80
# 267       3520.00
# 279       5773.26
# 293        500.00
# 318          1.00
# 347       2493.15
# 351       2109.59
# 374       7288.20
# 379       2032.88
# 437       9129.00
# 442       1691.33
# 446       2852.84
# 447       1876.55
# 448       3124.77
# 449       2701.83
# 450       2846.56
# 453       5512.27
# 457       2184.00
# 469       6218.32
# 512       5097.27
# 531       3690.25
# 532       3328.72
# ...           ...
# 1691290   1062.79
# 1691307   1500.00
# 1691311   1500.00
# 1691326    427.47
# 1691331    266.99
# 1691332   1500.00
# 1691338   1463.70
# 1691346    750.00
# 1691351   1300.00
# 1691355    173.57
# 1691366    219.97
# 1691376   1247.50
# 1691382    294.50
# 1691383    468.94
# 1691384   7927.54
# 1691387    197.72
# 1691390   1500.00
# 1691391    750.00
# 1691395   3500.00
# 1691396     34.02
# 1691405   1163.96
# 1691414   1212.69
# 1691416   4312.04
# 1691424   3500.00
# 1691434   1000.00
# 1691445     61.59
# 1691450    284.10
# 1691451   1500.00
# 1691453    958.90
# 1691486   7526.45
#
# [564726 rows x 15 columns]

# %% [markdown]
# #### Here we see that 2015 was a busy year for New York City

# %%
nyc_leave = nyc.groupby(['Fiscal_Year', 'Leave_Status_as_of_July_31']).size()
nyc_leave.unstack('Fiscal_Year')
# Out:
# Fiscal_Year                   2014    2015    2016
# Leave_Status_as_of_July_31
# ACTIVE                      454121  517986  469903
# CEASED                       43638  104117   64033
# ON LEAVE                      5387    7186    5959
# ON SEPARATION LEAVE            982    1231     955
# SEASONAL                      5397    6624    3967

# %%
# We see that a significant amount of employees jobs are terminated yearly:

# %% [markdown]
# #### Secondly we compare the years which are represented in the datasets

# %%
nyc.groupby('Fiscal_Year').size().plot(kind='bar')

# %% [markdown]
# ## Split the dataset by year

# %%
nyc14 = nyc[nyc['Fiscal_Year'] == 2014]
nyc15 = nyc[nyc['Fiscal_Year'] == 2015]
nyc16 = nyc[nyc['Fiscal_Year'] == 2016]

# %%
Name = nyc.Last_Name + "-"+ nyc.First_Name + "-" + nyc.Mid_Init
Name.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5           True
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13          True
# 14         False
# 15         False
# 16          True
# 17          True
# 18         False
# 19         False
# 20         False
# 21          True
# 22         False
# 23         False
# 24          True
# 25          True
# 26         False
# 27         False
# 28          True
# 29          True
#            ...
# 1691457     True
# 1691458     True
# 1691459     True
# 1691460     True
# 1691461     True
# 1691462     True
# 1691463     True
# 1691464     True
# 1691465     True
# 1691466     True
# 1691467     True
# 1691468     True
# 1691469     True
# 1691470     True
# 1691471     True
# 1691472     True
# 1691473     True
# 1691474     True
# 1691475     True
# 1691476     True
# 1691477     True
# 1691478     True
# 1691479     True
# 1691480     True
# 1691481     True
# 1691482     True
# 1691483     True
# 1691484     True
# 1691485     True
# 1691486     True
# dtype: bool

# %% [markdown]
# ## Comapring Departments and Job Titles

# %%
#nyc_top_agency = 
a = nyc.groupby(['Fiscal_Year', 'Agency_Name'])['TotalPay']

#nyc_top_agency = nyc_top_agency + nyc14.groupby(['Agency_Name', 'Fiscal_Year']).size().sort_values().tail(20)
#nyc_top_agency = nyc_top_agency + nyc16.groupby(['Agency_Name', 'Fiscal_Year']).size().sort_values().tail(20)
#nyc_top_agency.unstack('Fiscal_Year')

# %%
# data.groupby(['col1', 'col2'])['col3'].mean()

# %%
plt.figure(figsize = (12,6))
plt.title("Histogram of Total Salary")
sns.distplot(nyc15.TotalPay, color = 'darkblue')

# %%
nyc15.groupby('Leave_Status_as_of_July_31').size().plot(kind='bar')

# %% [markdown]
# http://matplotlib.org/gallery.html

# %% [markdown]
# How many employees per 'Agency Name'?

# %%
nyc.groupby('Agency_Name').size().sort_values()
# Out:
# Agency_Name
# DISTRICTING COMMISSION                 3
# BRONX COMMUNITY BOARD #3               6
# BRONX COMMUNITY BOARD #6               7
# BRONX COMMUNITY BOARD #1               7
# BROOKLYN COMMUNITY BOARD #9            8
# MANHATTAN COMMUNITY BOARD #9           9
# QUEENS COMMUNITY BOARD #14             9
# BROOKLYN COMMUNITY BOARD #3            9
# BROOKLYN COMMUNITY BOARD #14           9
# BROOKLYN COMMUNITY BOARD #10           9
# BRONX COMMUNITY BOARD #9               9
# BRONX COMMUNITY BOARD #8               9
# BRONX COMMUNITY BOARD #5               9
# BRONX COMMUNITY BOARD #2               9
# BROOKLYN COMMUNITY BOARD #11           9
# STATEN ISLAND COMMUNITY BD #3          9
# MANHATTAN COMMUNITY BOARD #7           9
# BROOKLYN COMMUNITY BOARD #6           10
# BROOKLYN COMMUNITY BOARD #16          10
# BROOKLYN COMMUNITY BOARD #7           10
# QUEENS COMMUNITY BOARD #13            10
# BROOKLYN COMMUNITY BOARD #12          10
# BROOKLYN COMMUNITY BOARD #2           10
# BROOKLYN COMMUNITY BOARD #18          10
# QUEENS COMMUNITY BOARD #11            10
# STATEN ISLAND COMMUNITY BD #1         10
# MANHATTAN COMMUNITY BOARD #12         10
# QUEENS COMMUNITY BOARD #4             10
# MANHATTAN COMMUNITY BOARD #11         10
# MANHATTAN COMMUNITY BOARD #10         10
#                                    ...
# LAW DEPARTMENT                      5590
# DEPARTMENT OF FINANCE               6706
# DEPT OF CITYWIDE ADMIN SVCS         7358
# HOUSING PRESERVATION & DVLPMNT      7367
# DEPT. OF HOMELESS SERVICES          7638
# COMMUNITY COLLEGE (BRONX)           8464
# COMMUNITY COLLEGE (QUEENSBORO)      9754
# COMMUNITY COLLEGE (LAGUARDIA)      11835
# COMMUNITY COLLEGE (KINGSBORO)      13000
# COMMUNITY COLLEGE (MANHATTAN)      14717
# DEPARTMENT OF TRANSPORTATION       16916
# DEPT OF ENVIRONMENT PROTECTION     20010
# ADMIN FOR CHILDREN'S SVCS          21232
# DEPT OF HEALTH/MENTAL HYGIENE      21434
# DEPARTMENT OF CORRECTION           36626
# NYC HOUSING AUTHORITY              42384
# DEPT OF ED PER DIEM TEACHERS       43349
# DEPARTMENT OF SANITATION           43600
# DEPARTMENT OF EDUCATION ADMIN      45051
# HRA/DEPT OF SOCIAL SERVICES        46302
# FIRE DEPARTMENT                    53869
# DEPT OF PARKS & RECREATION         54941
# Police Department                  55619
# POLICE DEPARTMENT                  59974
# DEPT OF ED HRLY SUPPORT STAFF      74787
# DEPT OF ED PARA PROFESSIONALS      92388
# BOARD OF ELECTION POLL WORKERS     95357
# POLICE DEPARTMENT                 124422
# DEPT OF ED PER SESSION TEACHER    244375
# DEPT OF ED PEDAGOGICAL            318709
# dtype: int64

# %% [markdown]
# Are there any duplicate names in the dataset?

# %%
nyc.

# %% [markdown]
# What is the averge length of employement?

# %%
nyc.Agency_Start_Date.mean()

# %% [markdown]
#  Which employee has been employed the longest?

# %%
nyc.Agen

# %% [markdown]
# What is the correlation between titles and salaries?

# %%
nyc.groupby(['Title_Description']).size()
# Out:
# Title_Description
#                                                                    6
# * ATTENDING DENTIST                                                2
# *ADM DIR FLEET MAINT-MGRL ASGMNT                                   2
# *ADM DIR FLEET MAINTENANCE - NM                                    3
# *ADM SCHOOL SECURITY MANAGER-U                                     8
# *ADMIN SCHL SECUR MGR-MGL                                          1
# *ADMIN SCHL SECUR MGR-MGL                                          2
# *ADMINISTRATIVE ATTORNEY                                           1
# *ADMINISTRATIVE ATTORNEY                                          15
# *ASIST SYSTMS ANALYST                                              6
# *ASSIST COORDINATING MANAGER                                      28
# *ASSOCIATE DIRECTOR HEALTH PROGRAM                                11
# *ASSOCIATE EXECUTIVE DIRECTOR                                     20
# *ATTORNEY AT LAW                                                   5
# *ATTORNEY AT LAW                                                 110
# *CERTIFIED APPLICATIONS DEVELOPER                                  2
# *CERTIFIED APPLICATIONS DEVELOPER                                 23
# *CERTIFIED DATABASE ADMINISTRATOR                                 25
# *CERTIFIED LOCAL AREA NETWORK ADMINISTRATOR                        3
# *CERTIFIED LOCAL AREA NETWORK ADMINISTRATOR                       41
# *CERTIFIED WIDE AREA NETWORK ADMINISTRATOR                         3
# *CERTIFIED WIDE AREA NETWORK ADMINISTRATOR                        40
# *COMMUNITY LIAISON WORKER                                          8
# *COOK                                                            145
# *COORDINATING MANAGER                                             72
# *CUSTODIAL ASSISTANT                                              91
# *DIR OF FISCAL AFFAIRS                                             3
# *DIRECTOR OF HEALTH CARE PROGRAM PLANNING/ANALYSIS                15
# *HOUSING CARETAKER                                                66
# *PERSONNEL PROGRAM DEVELOPEMENT SPECIALIST                         4
#                                                                 ...
# TRAFFIC ENFORCEMENT AGENT                                        272
# TRAFFIC ENFORCEMENT AGENT                                       5698
# TRAINER ASSISTANT                                                102
# TRANSPORTATION BOROUGH COMMISSIONER                                9
# TRANSPORTATION INSPECTOR                                           3
# UNIVERSITY ARCHITECT                                               5
# UNIVERSITY ASSISTANT ARCHITECT                                    11
# UNIVERSITY ASSISTANT ENGINEER                                      6
# UNIVERSITY ENGINEER                                                3
# UNIVERSITY ENGINEER TECH                                           4
# URBAN ARCHEOLOGIST                                                 6
# URBAN PARK RANGER                                               1040
# VICE PRESIDENT                                                    94
# VOTING MACHINE TECHNICIAN                                        297
# WARDEN                                                            87
# WARDEN-ASSISTANT DEPUTY WARDEN                                   222
# WARDEN-ASSISTANT DEPUTY WARDEN TED < 11/1/92                     109
# WARDEN-DEPUTY WARDEN                                              41
# WARDEN-DEPUTY WARDEN                                              44
# WARDEN-DEPUTY WARDEN IN COMM                                      22
# WARDEN-DEPUTY WARDEN IN COMM TED < 11/1/92                         4
# WARDEN-DEPUTY WARDEN TED < 11/1/92                                41
# WATER USE INSPECTOR                                              167
# WATERSHED MAINTAINER                                             800
# WELDER                                                             4
# WELDER                                                           110
# WIPER                                                             55
# WORKER'S COMPENSATION BENEFITS EXAMINER                          249
# X-RAY TECHNICIAN                                                  38
# YOUTH COORDINATOR                                                 34
# dtype: int64

# %% [markdown]
# What are the average hours worked?

# %%
nyc.Regular_Hours.mean()
# Out:
# 702.29114129824302

# %% [markdown]
# What is the avergae OT time worked?

# %%
nyc.OT_Hours.mean()
# Out:
# 64.438383965341714

# %%
nyc.OT_Hours.sum()
# Out:
# 108996624.34

# %% [markdown]
# What is the total OT paid?

# %%
nyc.Total_OT_Paid.sum()
# Out:
# 5820003367.4000006

# %% [markdown]
# #### What is the avarage hourly OT rate?
#
# We can later use this as a metrics against other city datasets.

# %%
# Average hourly rate for OT.
nyc.Total_OT_Paid.sum() / nyc.OT_Hours.sum()
# Out:
# 53.396179951824003

# %% [markdown]
# How have salaries changed between the years?

# %% [markdown]
# How have hours worked changed between the years?

# %%
nyc.columns
# Out:
# Index(['Fiscal_Year', 'Agency_Name', 'Last_Name', 'First_Name', 'Mid_Init',
#        'Agency_Start_Date', 'Title_Description', 'Leave_Status_as_of_July_31',
#        'Pay_Basis', 'Regular_Hours', 'Regular_Gross_Paid', 'OT_Hours',
#        'Total_OT_Paid', 'Total_Other_Pay', 'TotalPay'],
#       dtype='object')

# %%
nyc.groupby(nyc.Fiscal_Year).Regular_Hours.agg(sum)
# Out:
# Fiscal_Year
# 2014    5.560554e+06
# 2015    7.242389e+06
# 2016    5.758238e+06
# Name: Regular_Hours, dtype: float64

# %%
nyc_x = nyc.groupby(['Fiscal_Year' , 'Regular_Hours']) #.Regular_Hours.sum(axis=1)
nyc_x.sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-189-28cc3eb98006> in <module>()
#       1 nyc_x = nyc.groupby(['Fiscal_Year' , 'Regular_Hours']) #.Regular_Hours.sum(axis=1)
# ----> 2 nyc_x.sum(axis=0)
#
# TypeError: f() got an unexpected keyword argument 'axis'

# %%
for y in range(2014, 2017):
    print(y, (nyc.Fiscal_Year == y).sum())
# Out:
# 2014 509525
# 2015 637144
# 2016 544818

# %%
#pd.DataFrame(

for y in range(2014, 2017):
    x = (y, (nyc.Fiscal_Year == y), nyc.Total_OT_Paid.sum())

    
    print(x)
# Out:
# (2014, 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# 5           True
# 6           True
# 7           True
# 8           True
# 9           True
# 10          True
# 11          True
# 12          True
# 13          True
# 14          True
# 15          True
# 16          True
# 17          True
# 18          True
# 19          True
# 20          True
# 21          True
# 22          True
# 23          True
# 24          True
# 25          True
# 26          True
# 27          True
# 28          True
# 29          True
#            ...
# 1691457    False
# 1691458    False
# 1691459    False
# 1691460    False
# 1691461    False
# 1691462    False
# 1691463    False
# 1691464    False
# 1691465    False
# 1691466    False
# 1691467    False
# 1691468    False
# 1691469    False
# 1691470    False
# 1691471    False
# 1691472    False
# 1691473    False
# 1691474    False
# 1691475    False
# 1691476    False
# 1691477    False
# 1691478    False
# 1691479    False
# 1691480    False
# 1691481    False
# 1691482    False
# 1691483    False
# 1691484    False
# 1691485    False
# 1691486    False
# Name: Fiscal_Year, dtype: bool, 5820003367.4000006)
# (2015, 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
#            ...
# 1691457     True
# 1691458     True
# 1691459     True
# 1691460     True
# 1691461     True
# 1691462     True
# 1691463     True
# 1691464     True
# 1691465     True
# 1691466     True
# 1691467     True
# 1691468     True
# 1691469     True
# 1691470     True
# 1691471     True
# 1691472     True
# 1691473     True
# 1691474     True
# 1691475     True
# 1691476     True
# 1691477     True
# 1691478     True
# 1691479     True
# 1691480     True
# 1691481     True
# 1691482     True
# 1691483     True
# 1691484     True
# 1691485     True
# 1691486     True
# Name: Fiscal_Year, dtype: bool, 5820003367.4000006)
# (2016, 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
#            ...
# 1691457    False
# 1691458    False
# 1691459    False
# 1691460    False
# 1691461    False
# 1691462    False
# 1691463    False
# 1691464    False
# 1691465    False
# 1691466    False
# 1691467    False
# 1691468    False
# 1691469    False
# 1691470    False
# 1691471    False
# 1691472    False
# 1691473    False
# 1691474    False
# 1691475    False
# 1691476    False
# 1691477    False
# 1691478    False
# 1691479    False
# 1691480    False
# 1691481    False
# 1691482    False
# 1691483    False
# 1691484    False
# 1691485    False
# 1691486    False
# Name: Fiscal_Year, dtype: bool, 5820003367.4000006)

# %% [markdown]
# Can we split the dataset between males and females?

# %%
# Try to use https://www.gender-api.com

# %% [markdown]
# Can you make a bar plot or a histogram?

# %% [markdown]
# Can you compare two related quantities?

# %% [markdown]
# Can you make a scatterplot?

# %% [markdown]
# Can you make a time-series plot?

# %%
# How have salaries changed over time between different groups of people?

# %%
# How are base pay, overtime pay and benefits allocated between different groups?

# %%
# Is there any evidene of pay discrimination based on gender in this dataset?

# %%
# How is budget allocated based on different groups and responsibilities?

# %% [markdown]
# ### Having made these plots, what are some insights you get from them? Do you see any correlations? Is there a hypothesis you would like to investigate further? What other questions do they lead you to ask?

# %% [markdown]
# ### By now you’ve asked a bunch of questions, and found some neat insights. Is there an interesting narrative, a way of presenting the insights using text and plots from the above, that tells a compelling story? As you work out this story, what are some other trends/relationships you think will make it more complete?
